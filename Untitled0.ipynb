# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
x=pd.read_csv('/content/AIR QUALITY .csv')
x
# Out:
#            Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 0    01.12.2022   6:00 AM                 73    83                 5        3
# 1    01.12.2022  12:00 PM                 74    83                 5        3
# 2    01.12.2022  15:00:00                 73    84                 5        3
# 3    01.12.2022  18:00:00                 73    85                 5        3
# 4    01.12.2022  20:00:00                 75    84                 5        3
# ..          ...       ...                ...   ...               ...      ...
# 254  22.01.2023  22.00.00                 75    91                 6        3
# 255  23.01.2023   5.00.00                150   148                47        2
# 256  23.01.2023  11.00.00                150   148                47        2
# 257  23.01.2023  16.00.00                159   148                45        2
# 258  23.01.2023  23.00.00                159   148                45        2
#
#      Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 0               8               32     20   83
# 1               8               32     20   83
# 2               8               35     21   84
# 3               8               37     22   85
# 4               8               38     20   84
# ..            ...              ...    ...  ...
# 254             9               40     16   91
# 255             1               48     26  150
# 256             3               38     24  150
# 257             3               39     15  159
# 258             4               45     14  159
#
# [259 rows x 10 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x.head()
# Out:
#          Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 0  01.12.2022   6:00 AM                 73    83                 5        3
# 1  01.12.2022  12:00 PM                 74    83                 5        3
# 2  01.12.2022  15:00:00                 73    84                 5        3
# 3  01.12.2022  18:00:00                 73    85                 5        3
# 4  01.12.2022  20:00:00                 75    84                 5        3
#
#    Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 0             8               32     20   83
# 1             8               32     20   83
# 2             8               35     21   84
# 3             8               37     22   85
# 4             8               38     20   84

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               259 non-null    object
#  1   Time               259 non-null    object
#  2   Pariculate Matter  259 non-null    int64
#  3   PM10               259 non-null    int64
#  4   Nitrogen Dioxide   259 non-null    int64
#  5   Ammonia            259 non-null    int64
#  6   Sulphurdiode       259 non-null    int64
#  7   Carbon Monoxide    259 non-null    int64
#  8   Ozone              259 non-null    int64
#  9   AQI                259 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 20.4+ KB

# %%
x.tail()
# Out:
#            Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 254  22.01.2023  22.00.00                 75    91                 6        3
# 255  23.01.2023   5.00.00                150   148                47        2
# 256  23.01.2023  11.00.00                150   148                47        2
# 257  23.01.2023  16.00.00                159   148                45        2
# 258  23.01.2023  23.00.00                159   148                45        2
#
#      Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 254             9               40     16   91
# 255             1               48     26  150
# 256             3               38     24  150
# 257             3               39     15  159
# 258             4               45     14  159

# %%
x.shape
# Out:
# (259, 10)

# %%
x.describe()
# Out:
#        Pariculate Matter        PM10  Nitrogen Dioxide     Ammonia  \
# count         259.000000  259.000000        259.000000  259.000000
# mean           87.266409   87.583012         14.027027    2.509653
# std            39.026359   32.163039         17.319927    0.886431
# min             4.000000   27.000000          2.000000    1.000000
# 25%            63.500000   65.000000          4.000000    2.000000
# 50%            77.000000   77.000000          7.000000    2.000000
# 75%           117.500000  117.500000         15.000000    3.000000
# max           166.000000  150.000000         92.000000    5.000000
#
#        Sulphurdiode  Carbon Monoxide       Ozone         AQI
# count    259.000000       259.000000  259.000000  259.000000
# mean      12.447876        45.996139   16.185328   93.737452
# std        9.427415        18.082605   11.857210   34.556108
# min        1.000000        15.000000    1.000000   42.000000
# 25%        8.000000        35.000000   11.000000   70.000000
# 50%       10.000000        42.000000   15.000000   82.000000
# 75%       12.000000        52.000000   18.000000  123.500000
# max       61.000000       105.000000   86.000000  166.000000

# %%
x.isnull()
# Out:
#       Date   Time  Pariculate Matter   PM10  Nitrogen Dioxide  Ammonia  \
# 0    False  False              False  False             False    False
# 1    False  False              False  False             False    False
# 2    False  False              False  False             False    False
# 3    False  False              False  False             False    False
# 4    False  False              False  False             False    False
# ..     ...    ...                ...    ...               ...      ...
# 254  False  False              False  False             False    False
# 255  False  False              False  False             False    False
# 256  False  False              False  False             False    False
# 257  False  False              False  False             False    False
# 258  False  False              False  False             False    False
#
#      Sulphurdiode  Carbon Monoxide  Ozone    AQI
# 0           False            False  False  False
# 1           False            False  False  False
# 2           False            False  False  False
# 3           False            False  False  False
# 4           False            False  False  False
# ..            ...              ...    ...    ...
# 254         False            False  False  False
# 255         False            False  False  False
# 256         False            False  False  False
# 257         False            False  False  False
# 258         False            False  False  False
#
# [259 rows x 10 columns]

# %%
x.isnull().sum()
# Out:
# Date                 0
# Time                 0
# Pariculate Matter    0
# PM10                 0
# Nitrogen Dioxide     0
# Ammonia              0
# Sulphurdiode         0
# Carbon Monoxide      0
# Ozone                0
# AQI                  0
# dtype: int64

# %%
x.notnull().sum()
# Out:
# Date                 259
# Time                 259
# Pariculate Matter    259
# PM10                 259
# Nitrogen Dioxide     259
# Ammonia              259
# Sulphurdiode         259
# Carbon Monoxide      259
# Ozone                259
# AQI                  259
# dtype: int64

# %%
x.notnull().sum()
# Out:
# Date                 259
# Time                 259
# Pariculate Matter    259
# PM10                 259
# Nitrogen Dioxide     259
# Ammonia              259
# Sulphurdiode         259
# Carbon Monoxide      259
# Ozone                259
# AQI                  259
# dtype: int64

# %%
x.head(6)
# Out:
#          Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 0  01.12.2022   6:00 AM                 73    83                 5        3
# 1  01.12.2022  12:00 PM                 74    83                 5        3
# 2  01.12.2022  15:00:00                 73    84                 5        3
# 3  01.12.2022  18:00:00                 73    85                 5        3
# 4  01.12.2022  20:00:00                 75    84                 5        3
# 5  02.12.2022  04:00:00                 78    80                 5        3
#
#    Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 0             8               32     20   83
# 1             8               32     20   83
# 2             8               35     21   84
# 3             8               37     22   85
# 4             8               38     20   84
# 5             9               38     12   80

# %%
x.nunique()
# Out:
# Date                  54
# Time                  48
# Pariculate Matter    114
# PM10                  87
# Nitrogen Dioxide      41
# Ammonia                5
# Sulphurdiode          36
# Carbon Monoxide       68
# Ozone                 39
# AQI                   98
# dtype: int64

# %%
x.value_counts
# Out:
# <bound method DataFrame.value_counts of            Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 0    01.12.2022   6:00 AM                 73    83                 5        3
# 1    01.12.2022  12:00 PM                 74    83                 5        3
# 2    01.12.2022  15:00:00                 73    84                 5        3
# 3    01.12.2022  18:00:00                 73    85                 5        3
# 4    01.12.2022  20:00:00                 75    84                 5        3
# ..          ...       ...                ...   ...               ...      ...
# 254  22.01.2023  22.00.00                 75    91                 6        3
# 255  23.01.2023   5.00.00                150   148                47        2
# 256  23.01.2023  11.00.00                150   148                47        2
# 257  23.01.2023  16.00.00                159   148                45        2
# 258  23.01.2023  23.00.00                159   148                45        2
#
#      Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 0               8               32     20   83
# 1               8               32     20   83
# 2               8               35     21   84
# 3               8               37     22   85
# 4               8               38     20   84
# ..            ...              ...    ...  ...
# 254             9               40     16   91
# 255             1               48     26  150
# 256             3               38     24  150
# 257             3               39     15  159
# 258             4               45     14  159
#
# [259 rows x 10 columns]>

# %%
x.sort_values
# Out:
# <bound method DataFrame.sort_values of            Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 0    01.12.2022   6:00 AM                 73    83                 5        3
# 1    01.12.2022  12:00 PM                 74    83                 5        3
# 2    01.12.2022  15:00:00                 73    84                 5        3
# 3    01.12.2022  18:00:00                 73    85                 5        3
# 4    01.12.2022  20:00:00                 75    84                 5        3
# ..          ...       ...                ...   ...               ...      ...
# 254  22.01.2023  22.00.00                 75    91                 6        3
# 255  23.01.2023   5.00.00                150   148                47        2
# 256  23.01.2023  11.00.00                150   148                47        2
# 257  23.01.2023  16.00.00                159   148                45        2
# 258  23.01.2023  23.00.00                159   148                45        2
#
#      Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 0               8               32     20   83
# 1               8               32     20   83
# 2               8               35     21   84
# 3               8               37     22   85
# 4               8               38     20   84
# ..            ...              ...    ...  ...
# 254             9               40     16   91
# 255             1               48     26  150
# 256             3               38     24  150
# 257             3               39     15  159
# 258             4               45     14  159
#
# [259 rows x 10 columns]>

# %%
x.fillna(0, inplace=True)
x
# Out:
#            Date      Time  Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  \
# 0    01.12.2022   6:00 AM                 73    83                 5        3
# 1    01.12.2022  12:00 PM                 74    83                 5        3
# 2    01.12.2022  15:00:00                 73    84                 5        3
# 3    01.12.2022  18:00:00                 73    85                 5        3
# 4    01.12.2022  20:00:00                 75    84                 5        3
# ..          ...       ...                ...   ...               ...      ...
# 254  22.01.2023  22.00.00                 75    91                 6        3
# 255  23.01.2023   5.00.00                150   148                47        2
# 256  23.01.2023  11.00.00                150   148                47        2
# 257  23.01.2023  16.00.00                159   148                45        2
# 258  23.01.2023  23.00.00                159   148                45        2
#
#      Sulphurdiode  Carbon Monoxide  Ozone  AQI
# 0               8               32     20   83
# 1               8               32     20   83
# 2               8               35     21   84
# 3               8               37     22   85
# 4               8               38     20   84
# ..            ...              ...    ...  ...
# 254             9               40     16   91
# 255             1               48     26  150
# 256             3               38     24  150
# 257             3               39     15  159
# 258             4               45     14  159
#
# [259 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Pariculate Matter'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Nitrogen Dioxide'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Ammonia'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Sulphurdiode'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Carbon Monoxide'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Ozone'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['AQI'])

# %%
sns.histplot(x="Pariculate Matter",data=x)
# Out:
# <Axes: xlabel='Pariculate Matter', ylabel='Count'>

# %%
sns.histplot(x="Nitrogen Dioxide",data=x)
# Out:
# <Axes: xlabel='Nitrogen Dioxide', ylabel='Count'>

# %%
sns.histplot(x="Ammonia",data=x)
# Out:
# <Axes: xlabel='Ammonia', ylabel='Count'>

# %%
sns.histplot(x="Sulphurdiode",data=x)
# Out:
# <Axes: xlabel='Sulphurdiode', ylabel='Count'>

# %%
sns.histplot(x="Carbon Monoxide",data=x)
# Out:
# <Axes: xlabel='Carbon Monoxide', ylabel='Count'>

# %%
sns.histplot(x="Ozone",data=x)
# Out:
# <Axes: xlabel='Ozone', ylabel='Count'>

# %%
sns.histplot(x="AQI",data=x)
# Out:
# <Axes: xlabel='AQI', ylabel='Count'>

# %%
x=x.iloc[:,2:10]
y=x.iloc[:,3:4]
print(x,'\n',y)
# Out:
#      Pariculate Matter  PM10  Nitrogen Dioxide  Ammonia  Sulphurdiode  \
# 0                   73    83                 5        3             8
# 1                   74    83                 5        3             8
# 2                   73    84                 5        3             8
# 3                   73    85                 5        3             8
# 4                   75    84                 5        3             8
# ..                 ...   ...               ...      ...           ...
# 254                 75    91                 6        3             9
# 255                150   148                47        2             1
# 256                150   148                47        2             3
# 257                159   148                45        2             3
# 258                159   148                45        2             4
#
#      Carbon Monoxide  Ozone  AQI
# 0                 32     20   83
# 1                 32     20   83
# 2                 35     21   84
# 3                 37     22   85
# 4                 38     20   84
# ..               ...    ...  ...
# 254               40     16   91
# 255               48     26  150
# 256               38     24  150
# 257               39     15  159
# 258               45     14  159
#
# [259 rows x 8 columns]
#       Ammonia
# 0          3
# 1          3
# 2          3
# 3          3
# 4          3
# ..       ...
# 254        3
# 255        2
# 256        2
# 257        2
# 258        2
#
# [259 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=2)
print(X_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (207, 8)
# (207, 1)
# (52, 8)
# (52, 1)

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
cc=svm.SVR(kernel='linear')

# %%
cl=cc.fit(X_train,y_train.values.ravel())

# %%
yp=cl.predict(x_test)
print(yp)
# Out:
# [4.89355744 1.05662708 1.11174934 1.0477268  2.0098129  2.09630746
#  2.02625427 3.88650329 1.96392029 1.06111732 2.97571545 2.09032201
#  2.08327351 3.93843194 3.08902158 2.01091844 4.03692269 4.03027719
#  2.05368394 3.00864736 2.09840221 3.01009706 2.0473112  2.99077211
#  3.91485741 2.90155604 2.09110105 2.96932046 4.87225841 1.03506104
#  2.0655538  4.05772374 2.88966667 2.06033902 2.93256258 3.03927645
#  2.91959375 3.97255674 3.08159928 1.08378098 2.01356955 2.04324894
#  2.0255492  2.02640256 2.01088246 2.89550632 2.97345011 2.96812499
#  1.06821706 3.96497782 2.03334717 1.04480248]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(np.sqrt(mean_squared_error(y_test,yp)))
svm=mean_squared_error(y_test,yp )
print(svm)
print(mean_absolute_error(y_test,yp ))
# Out:
# 0.06526046799890543
# 0.0042589286834361605
# 0.05626144820533606

# %% [markdown]
# K-NEAREST NEIGHBOURS

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score
kk=KNeighborsRegressor()
kl=kk.fit(X_train, y_train.values.ravel())

# %%
yp=kl.predict(x_test)
print(yp)
print(y_test)
# Out:
# [3.6 1.4 1.4 1.4 2.8 2.8 2.  3.  1.4 1.2 3.  3.  2.6 3.6 2.8 2.6 3.4 3.4
#  1.8 2.8 2.8 2.6 2.  3.  3.6 2.6 2.2 3.  3.4 1.4 2.  3.4 1.8 2.  3.  3.4
#  2.2 3.4 2.8 1.8 1.6 2.8 2.6 2.8 2.  2.  3.  3.  1.2 3.4 2.  1.4]
#      Ammonia
# 30         5
# 244        1
# 140        1
# 10         1
# 181        2
# 160        2
# 192        2
# 35         4
# 101        2
# 13         1
# 3          3
# 134        2
# 133        2
# 93         4
# 54         3
# 180        2
# 112        4
# 111        4
# 71         2
# 236        3
# 161        2
# 235        3
# 41         2
# 233        3
# 84         4
# 209        3
# 130        2
# 171        3
# 249        5
# 109        1
# 65         2
# 114        4
# 24         3
# 66         2
# 251        3
# 214        3
# 20         3
# 28         4
# 53         3
# 142        1
# 74         2
# 128        2
# 229        2
# 228        2
# 227        2
# 23         3
# 173        3
# 147        3
# 14         1
# 29         4
# 158        2
# 18         1

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(np.sqrt(mean_squared_error(y_test,yp)))
knn=mean_squared_error(y_test,yp )
print(knn)
print(mean_absolute_error(y_test,yp ))
# Out:
# 0.6
# 0.35999999999999993
# 0.46153846153846145

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
rfc = RandomForestRegressor()

# %%
rr=rfc.fit(X_train,y_train.values.ravel())
yp=rr.predict(x_test)
print(yp)
# Out:
# [4.73 1.   1.   1.   2.   2.   2.   4.   2.   1.   3.   2.   2.   4.
#  3.   2.   4.   4.   2.   3.   2.   3.   2.   3.   4.   3.   2.   3.
#  4.54 1.   2.   4.   3.   2.   3.   3.   3.   4.   3.   1.   2.   2.
#  2.   2.   2.   3.   3.   3.   1.   4.   2.   1.  ]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(np.sqrt(mean_squared_error(y_test,yp)))
rf=mean_squared_error(y_test,yp )
print(rf)
print(mean_absolute_error(y_test,yp ))
# Out:
# 0.07396724846953442
# 0.005471153846153842
# 0.01403846153846153

# %% [markdown]
# XG BOOST

# %%
from xgboost import XGBRegressor
from math import sqrt
from sklearn import metrics
regressor = XGBRegressor()
regressor.fit(X_train, y_train)
# prediction on training data
training_data_prediction = regressor.predict(X_train)
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(mean_absolute_error(y_train,training_data_prediction))
print(mean_squared_error(y_train,training_data_prediction))
mse=mean_squared_error(y_train,training_data_prediction)
xgb=(mse)
print("MSE of Training =",sqrt(xgb))
# R squared Value
r2_train = metrics.r2_score(y_train, training_data_prediction)
# prediction on test data
test_data_prediction = regressor.predict(x_test)
'''mse2 = mean_squared_error(Y_test,training_data_prediction)'''
'''print("MSE of test =",mse2)'''
# R squared Value
r2_test = metrics.r2_score(y_test, test_data_prediction)
print('R Squared value = ', r2_train)
print('R Squared value = ', r2_test)
# Out:
# 5.1570975262185804e-05
# 1.0192117543927205e-08
# MSE of Training = 0.00010095601786880862
# R Squared value =  0.9999999855246257
# R Squared value =  0.9999999745674636

# %% [markdown]
# BAYESIAN RIDGE

# %%
import numpy as np
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
x=pd.read_csv("/content/AIR QUALITY .csv")
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=2)
# Create a Bayesian Ridge Regression model
model = BayesianRidge()
# Calculate the Mean Squared Error (MSE)
br = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", br)
mae = mean_absolute_error(y_test,y_pred)
print("mae:",mae)
print("rmse:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Squared Error: 4.835565644984568e-30
# mae: 1.750736308062747e-15
# rmse: 2.1989919611004873e-15

# %%
models = pd.DataFrame({
    'Model':[ 'KNeighbours', 'SVM', 'Random Forest','XG Boost','Bayesian Ridge'],
    'Error_score' :[ knn, svm, rf, xgb, br]
})
models
sns.barplot(x='Error_score', y='Model', data=models)
models.sort_values(by='Error_score', ascending=False)
# Out:
#             Model   Error_score
# 0     KNeighbours  3.600000e-01
# 2   Random Forest  5.471154e-03
# 1             SVM  4.258929e-03
# 3        XG Boost  1.019212e-08
# 4  Bayesian Ridge  4.835566e-30
